# %% [markdown]
# <a href="https://colab.research.google.com/github/pioneer123456/Smart-ML-based-Refrigerator/blob/main/Generating_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader

# %%
# !mkdir images

# %%
from bing_image_downloader import downloader
downloader.download("fresh_banana_fruit",limit= 50,output_dir="images")
# Out:
# [%] Downloading Images to /content/images/ fresh_banana_fruit
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 17 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://thumbs.dreamstime.com/z/single-fresh-banana-fruit-isolated-12871847.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://5.imimg.com/data5/SELLER/Default/2021/1/PO/WT/JM/12525600/cashew-nuts-500x500.png
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://3.imimg.com/data3/ON/BC/MY-11284249/fresh-banana-250x250.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://4.bp.blogspot.com/-GSLHAbGF6ng/TkKxy5xZHhI/AAAAAAAAAjQ/A4CdAcICIns/s1600/s+IMG_1403q.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://images.all-free-download.com/images/graphicthumb/fresh_banana_picture_167146.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://www.ismartfashions.com/wp-content/uploads/2020/06/Bananas-best-fruit-300x212.jpg
# [%] File Downloaded !
#
# ...

# %%
# !zip -r /content/images/fresh_banana_fruit.zip "/content/images/ fresh_banana_fruit"
# Out:
#   adding: content/images/ fresh_banana_fruit/ (stored 0%)
#   adding: content/images/ fresh_banana_fruit/Image_5.jpg (deflated 2%)
#   adding: content/images/ fresh_banana_fruit/Image_24.jpg (deflated 6%)
#   adding: content/images/ fresh_banana_fruit/Image_1.jpg (deflated 14%)
#   adding: content/images/ fresh_banana_fruit/Image_29.jpeg (deflated 8%)
#   adding: content/images/ fresh_banana_fruit/Image_39.jpg (deflated 2%)
#   adding: content/images/ fresh_banana_fruit/Image_20.jpg (deflated 5%)
#   adding: content/images/ fresh_banana_fruit/Image_46.jpg (deflated 6%)
#   adding: content/images/ fresh_banana_fruit/Image_10.jpg (deflated 7%)
#   adding: content/images/ fresh_banana_fruit/Image_44.jpg (deflated 13%)
#   adding: content/images/ fresh_banana_fruit/Image_27.jpg (deflated 7%)
#   adding: content/images/ fresh_banana_fruit/Image_26.jpg (deflated 0%)
#   adding: content/images/ fresh_banana_fruit/Image_22.jpg (deflated 1%)
# ...

# %%
from google.colab import files
files.download("/content/images/fresh_banana_fruit.zip")

# %%
downloader.download("rotten_banana_fruit",limit= 50,output_dir="images")
# Out:
# [%] Downloading Images to /content/images/rotten_banana_fruit
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 14 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://thumbs.dreamstime.com/z/rotten-banana-fruit-wooden-board-fruits-bunch-black-wild-asian-cultivated-cutting-55287197.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://media.istockphoto.com/vectors/rotten-banana-day-4-decayed-yellow-fruit-old-spoiled-fetus-vector-id687867816?k=6&amp;m=687867816&amp;s=170667a&amp;w=0&amp;h=hpM3d2XVkQMK70oOSZ8Du1UUR_7LNQrOXH27gbJSiv8=
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://t4.ftcdn.net/jpg/01/25/76/61/500_F_125766102_Ck3di9BtAVkYx1SJsIKvegK3qj8MZS2b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://thumbs.dreamstime.com/z/rotten-banana-day-decayed-yellow-fruit-old-spoiled-fetus-81152188.jpg
# [%] File Downloaded !
#
# ...

# %%
# !zip -r /content/images/rotten_banana_fruit.zip "/content/images/rotten_banana_fruit"
# Out:
#   adding: content/images/rotten_banana_fruit/ (stored 0%)
#   adding: content/images/rotten_banana_fruit/Image_5.jpg (deflated 0%)
#   adding: content/images/rotten_banana_fruit/Image_24.jpg (deflated 0%)
#   adding: content/images/rotten_banana_fruit/Image_1.jpg (deflated 1%)
#   adding: content/images/rotten_banana_fruit/Image_42.png (deflated 0%)
#   adding: content/images/rotten_banana_fruit/Image_39.jpg (deflated 13%)
#   adding: content/images/rotten_banana_fruit/Image_20.jpg (deflated 1%)
#   adding: content/images/rotten_banana_fruit/Image_46.jpg (deflated 3%)
#   adding: content/images/rotten_banana_fruit/Image_10.jpg (deflated 3%)
#   adding: content/images/rotten_banana_fruit/Image_44.jpg (deflated 16%)
#   adding: content/images/rotten_banana_fruit/Image_27.jpg (deflated 0%)
#   adding: content/images/rotten_banana_fruit/Image_33.png (deflated 1%)
#   adding: content/images/rotten_banana_fruit/Image_29.jpg (deflated 14%)
# ...

# %%
from google.colab import files
files.download("/content/images/rotten_banana_fruit.zip")

# %%
from bing_image_downloader import downloader
downloader.download("juicy_apple_fruit",limit= 50,output_dir="images")
# Out:
# [%] Downloading Images to /content/images/juicy_apple_fruit
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 16 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://sc01.alicdn.com/kf/HTB1pTqOKqmWBuNjy1Xaq6xCbXXa3/228763553/HTB1pTqOKqmWBuNjy1Xaq6xCbXXa3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://images.freeimages.com/images/large-previews/e03/juicy-apples-1329357.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://images.fineartamerica.com/images-medium-large-5/juicy-super-fresh-apple-alstair-thane.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://thumbs.dreamstime.com/z/two-fresh-juicy-apples-11732774.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://images.freeimages.com/images/premium/previews/5272/5272309-juicy-apples.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://thumbs.dreamstime.com/z/juicy-apple-15921242.jpg
# [%] File Downloaded !
#
# ...

# %%
# !zip -r /content/images/juicy_apple_fruit.zip "/content/images/juicy_apple_fruit"
# Out:
#   adding: content/images/juicy_apple_fruit/ (stored 0%)
#   adding: content/images/juicy_apple_fruit/Image_5.jpg (deflated 0%)
#   adding: content/images/juicy_apple_fruit/Image_24.jpg (deflated 0%)
#   adding: content/images/juicy_apple_fruit/Image_1.jpg (deflated 0%)
#   adding: content/images/juicy_apple_fruit/Image_39.jpg (deflated 5%)
#   adding: content/images/juicy_apple_fruit/Image_20.jpg (deflated 7%)
#   adding: content/images/juicy_apple_fruit/Image_46.jpg (deflated 11%)
#   adding: content/images/juicy_apple_fruit/Image_10.jpg (deflated 9%)
#   adding: content/images/juicy_apple_fruit/Image_44.jpg (deflated 19%)
#   adding: content/images/juicy_apple_fruit/Image_14.JPG (deflated 1%)
#   adding: content/images/juicy_apple_fruit/Image_29.jpg (deflated 0%)
#   adding: content/images/juicy_apple_fruit/Image_26.jpg (deflated 4%)
#   adding: content/images/juicy_apple_fruit/Image_22.jpg (deflated 0%)
#   adding: content/images/juicy_apple_fruit/Image_49.jpg (deflated 50%)
# ...

# %%
from google.colab import files
files.download("/content/images/juicy_apple_fruit.zip")

# %%
from bing_image_downloader import downloader
downloader.download("defected_apple_fruit",limit= 50,output_dir="images")
# Out:
# [%] Downloading Images to /content/images/defected_apple_fruit
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 9 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://growingfruit-images.s3.dualstack.us-west-2.amazonaws.com/original/3X/b/a/ba47e20e121a8d1f3e319b3caab582d52ca3c9a7.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.qdalliance.com/data/thumb/res/en/20170901/59c88b052befd100.jpg_20170901133919_630x480.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i5.walmartimages.com/asr/7e112ed7-3e92-49cf-b067-267fe241d665.9ef80e8a5a7360b8560ca06e706fa3f7.jpeg?odnWidth=612&amp;odnHeight=612&amp;odnBg=ffffff
# [Error]Invalid image, not saving https://i5.walmartimages.com/asr/7e112ed7-3e92-49cf-b067-267fe241d665.9ef80e8a5a7360b8560ca06e706fa3f7.jpeg?odnWidth=612&amp;odnHeight=612&amp;odnBg=ffffff
#
# ...
